# %%
# This cell does not get executed when run with Times Square
import os
import datetime

visit_origin = os.environ.get("SCHEDVIEW_VISIT_ORIGIN", "lsstcam")
day_obs = int(
    os.environ.get(
        "SCHEDVIEW_DAY_OBS",
        (datetime.date.today() - datetime.timedelta(days=1)).strftime("%Y%m%d"),
    )
)
sim_date = datetime.date.fromisoformat(
    os.environ.get(
        "SCHEDVIEW_SIM_DATE",
        datetime.date(day_obs // 10000, (day_obs % 10000) // 100, day_obs % 100).isoformat(),
    )
)


"""
# To render this notebook to html, in the current directory with the current python environment

export SCHEDVIEW_VISIT_ORIGIN=lsstcam
export SCHEDVIEW_DAY_OBS='20260305'
export SCHEDVIEW_SIM_DATE='2026-03-05'
jupyter nbconvert \
    --to html \
    --execute \
    --no-input \
    --ExecutePreprocessor.kernel_name=python3 \
    --ExecutePreprocessor.startup_timeout=3600 \
    --ExecutePreprocessor.timeout=3600 \
    compareprenight.ipynb

# The public USDF page served at
#    https://usdf-rsp-int.slac.stanford.edu/schedview-static-pages/compareprenight/lsstcam/2026/03/05/comparenight_2026-03-05.html
# is found at
#    /sdf/data/rubin/shared/scheduler/reports/compareprenight/lsstcam/2026/03/05/compareprenight_2026-03-05.html
"""
pass

# %%
DEBUG = False

if DEBUG:
    day_obs = 20260327
    sim_date = datetime.date.fromisoformat("20260327")

# %%
from IPython.display import display, HTML, Markdown
from functools import partial
import datetime
import math
import sys
import os
import yaml
from urllib.parse import urlparse
import warnings
import itertools
import healpy as hp
import pandas as pd
import numpy as np
import astropy
import bokeh
import bokeh.io
import boto3
import colorcet
from erfa import ErfaWarning
from astropy.time import Time

# %%
from sklearn.neighbors import KernelDensity

# %%
usdf_sim_data_dir = "/sdf/data/rubin/shared/rubin_sim_data"
if os.path.exists(usdf_sim_data_dir):
    os.environ["RUBIN_SIM_DATA_DIR"] = "/sdf/data/rubin/shared/rubin_sim_data"

# %%
import os
import sys

if DEBUG:
    sched_source = "devel"
else:
    sched_source = "shared"
    # sched_source = 'env'

match sched_source:
    case "shared":
        if os.path.exists("/sdf/data/rubin/shared/scheduler/packages"):
            sys.path.insert(0, "/sdf/data/rubin/shared/scheduler/packages/uranography")
            sys.path.insert(0, "/sdf/data/rubin/shared/scheduler/packages/rubin_scheduler")
            sys.path.insert(0, "/sdf/data/rubin/shared/scheduler/packages/rubin_sim")
            sys.path.insert(0, "/sdf/data/rubin/shared/scheduler/packages/schedview")
            sys.path.insert(0, "/sdf/data/rubin/shared/scheduler/packages/rubin_nights")
    case "devel":
        if os.path.exists("/sdf/data/rubin/user/neilsen/devel"):
            sys.path.insert(0, "/sdf/data/rubin/user/neilsen/devel/rubin_scheduler")
            sys.path.insert(0, "/sdf/data/rubin/user/neilsen/devel/rubin_sim")
            sys.path.insert(0, "/sdf/data/rubin/user/neilsen/devel/schedview")
            sys.path.insert(0, "/sdf/data/rubin/user/neilsen/devel/uranography")
            sys.path.insert(0, "/sdf/data/rubin/user/neilsen/devel/rubin_nights")
    case _:
        # Use whatever is in the kernel python environment
        pass

# %%
from schedview.util import config_logging_for_reports
import logging

config_logging_for_reports(logging.ERROR)

# %%
import rubin_scheduler
import rubin_scheduler.utils
import rubin_sim.sim_archive
from rubin_scheduler.scheduler.model_observatory import ModelObservatory
from rubin_sim import maf
import uranography

from lsst.resources import ResourcePath

import schedview.compute
import schedview.compute.visits
import schedview.collect
import schedview.collect.rewards
import schedview.collect.visits
import schedview.collect.sv
import schedview.plot
import schedview.plot.rewards
import schedview.plot.visit_skymaps
from schedview import DayObs
from rubin_sim.sim_archive.vseqmetadata import VisitSequenceArchiveMetadata
from rubin_nights.reference_values import SCIENCE_PROGRAMS
from rubin_scheduler.scheduler.utils import get_current_footprint
from schedview import RA_COL, DECL_COL, POINTING_COL

# %%
display(Markdown(f"# Comparison of completed visits from dayobs {day_obs} and the simulations of it completed on {sim_date}"))

# %% [markdown]
# This report compares completed visits (as queried from the consdb) for a night to the pre-night simulated visits for that night.
#
# It is similar to the report that displays multiple pre-night simulations for one night, but includes the completed visits as well.

# %%
# Degraded IERS accuracy is never going to be important for these figures.

# If IERS degraded accuracy encountered, don't fail, just keep going.
astropy.utils.iers.conf.iers_degraded_accuracy = "ignore"

# %%
bokeh.io.output_notebook(hide_banner=True)

# %%
# %matplotlib inline

# %%
archive_uri = "s3://rubin:rubin-scheduler-prenight/opsim/"

if urlparse(archive_uri).scheme.upper() == "S3":
    os.environ["LSST_DISABLE_BUCKET_VALIDATION"] = "1"
    os.environ["S3_ENDPOINT_URL"] = "https://s3dfrgw.slac.stanford.edu/"

# nside=2**18 is about 1 arcsec resolution
pointing_hpix_nside = 2**18

# field_coord_tolerance_deg is how close
# completed visit needs to be to a healpix
# center for it to count as observing that
# healpix field. (degrees)
field_coord_tolerance_deg = 10.0 / (60 * 60)


day_obs = DayObs.from_date(day_obs)
day_obs_mjd = day_obs.mjd
observatory = ModelObservatory(init_load_length=1)
timezone = "Chile/Continental"
telescope = "auxtel" if visit_origin.lower() == "latiss" else "simonyi"

# %%
# Load simulated visits from the visit sequence archive

simulated_visits = schedview.collect.multisim.read_multiple_prenights(sim_date, day_obs, telescope=telescope)
if len(simulated_visits) < 1:
    display(HTML("<b>No simulated visits found on this night.</b>"))
    sys.exit(0)

simulated_visits["visitseq_uuid"] = simulated_visits["visitseq_uuid"].apply(str)

# %%
# Retrieve completed visits from consdb

completed_visits = schedview.collect.visits.read_visits(
    day_obs,
    visit_origin,
    stackers=schedview.collect.visits.NIGHT_STACKERS,
    num_nights=1,
)

# Filter out visits that should not be compared to simulations

if visit_origin == "lsstcam":
    completed_visits = completed_visits.loc[completed_visits["science_program"].isin(SCIENCE_PROGRAMS), :]

if "can_see_sky" in completed_visits.columns:
    completed_visits = completed_visits.loc[completed_visits.can_see_sky.fillna(True).astype(bool), :]

no_visits = len(completed_visits) == 0

if no_visits:
    display(HTML("<b>No completed visits found on this night.</b>"))

# %%
# Assign pointing ids to both simulated and completed visits.
# When they get merged, the pointing ids associated with the completed visits may get overwritten.

simulated_visits.loc[:, POINTING_COL] = hp.ang2pix(
    nside=pointing_hpix_nside,
    theta=simulated_visits.loc[:, RA_COL].to_numpy(),
    phi=simulated_visits.loc[:, DECL_COL].to_numpy(),
    lonlat=True,
)
completed_visits.loc[:, POINTING_COL] = hp.ang2pix(
    nside=pointing_hpix_nside,
    theta=completed_visits.loc[:, RA_COL].to_numpy(),
    phi=completed_visits.loc[:, DECL_COL].to_numpy(),
    lonlat=True,
)

reference_pointings = simulated_visits.loc[:, [POINTING_COL, RA_COL, DECL_COL]].drop_duplicates().sort_values(POINTING_COL).set_index(POINTING_COL)

# %%
# Combine the completed and simulated visits into a single DataFrame with all the needed columns.

start_time = DayObs.from_date(day_obs).sun_n12_setting if no_visits else Time(completed_visits.observationStartMJD.min(), format="mjd")
scheduler_version = schedview.collect.get_version_at_time("rubin_scheduler", start_time)

visits = schedview.compute.comparesim.combine_completed_with_sims(
    simulated_visits,
    completed_visits,
    scheduler_version,
    reference_pointings=reference_pointings,
    pointing_tolerance=field_coord_tolerance_deg,
)

# %%
# Set visual elements for different visit sets (sims or completed)
sim_labels = visits["label"].unique()
sim_color_mapper, sim_color_dict, sim_marker_mapper, sim_hatch_dict = schedview.plot.generate_sim_indicators(sim_labels)

# %% [markdown]
# ## Map of visits

# %%
footprint_depth_by_band, footprint_regions = get_current_footprint(64)

# %%
builder = (
    schedview.plot.visit_skymaps.VisitMapBuilder(
        None if no_visits else visits.query("sim_index == 0"),
        mjd=day_obs.sunrise.mjd if no_visits else visits["observationStartMJD"].max(),
        map_classes=[
            uranography.armillary.ArmillarySphere,
            uranography.planisphere.Planisphere,
        ],
    )
    .add_visit_patches()
    .add_alt_visit_patches(visits.query("sim_index > 0"))
    .add_footprint_outlines(footprint_regions)
    .add_eq_sliders()
    .add_alt_visits_selector()
    .add_ecliptic()
    .add_galactic_plane()
    .add_datetime_slider()
    .hide_mjd_slider()
    .add_graticules()
    .add_body("sun", size=15, color="yellow", alpha=1.0)
    .add_body("moon", size=15, color="orange", alpha=0.8)
    .add_horizon()
    .add_horizon(zd=70, color="red")
    .add_hovertext()
)
if not no_visits:
    builder.hide_future_visits()

viewable = builder.build()
bokeh.io.show(viewable)

# %% [markdown]
# The above plots show the simulated and collected visits in two different representations, modeled after physical observing tools.
#
#  - The [Orthographic projection](https://en.wikipedia.org/wiki/Orthographic_projection) on the left is intended to be used as a virtual [armillary sphere](https://en.wikipedia.org/wiki/Armillary_sphere): a spherical representation of the sky whose orientation with respect to the horizon can be shown as a function of time. The time for which the orientation applies is set by the "Date and time (UTC)" slider, and the orientation from which the user views the figure is controlled by the "center alt" and "center az" sliders, which set the coordinates of the center of the figure. The figure is always oriented so zenith us "up" on the screen. The orthogrophic projection is not an equal-area projection, but playing with the sliders is a helpful way to inform a human's spatial reasoning in three dimensions.
#  - The [Lambert Azimuthal Equal Area Projection](https://en.wikipedia.org/wiki/Lambert_azimuthal_equal-area_projection) on the left, centered at the south celestial pole, is intended to be used as a virtual [planisphere](https://en.wikipedia.org/wiki/Planisphere), with the "Date and time (UTC)" slider setting the time. R.A. increases counterclockwise. The projection used is equal area, but highly distorted near the north celestial pole (outside the LSST footprint). This is a particularly helpful representation for planning observing, because changes in time in relevant features are simple rotations, without alterations in distortion, and there are no discontinuities anywhere in the footprint at any time of year.
#
# Both plots show the footprints of camera pointing taken up to the time set by the MJD slider, with the most recent three pointings outlined in cyan:
#
#  - <span style='background-color:#1600ea'>&nbsp;&nbsp;&nbsp;</span><span style='color:#1600ea'> blue</span>: u band
#  - <span style='background-color:#31de1f'>&nbsp;&nbsp;&nbsp;</span><span style='color:#31de1f'> green</span>: g band
#  - <span style='background-color:#b52626'>&nbsp;&nbsp;&nbsp;</span><span style='color:#b52626'> red</span>: r band
#  - <span style='background-color:#370201'>&nbsp;&nbsp;&nbsp;</span><span style='color:#370201'> brown</span>: i band
#  - <span style='background-color:#ba52ff'>&nbsp;&nbsp;&nbsp;</span><span style='color:#ba52ff'> purple</span>: z band
#  - <span style='background-color:#61a2b3'>&nbsp;&nbsp;&nbsp;</span><span style='color:#61a2b3'> teal</span>: y band
#
# Both plots have the following additional annotations:
#  - The thick gray lines show the boundries of different areas of the LSST footprint.
#  - The orange disk shows the coordinates of the moon.
#  - The yellow disk shows the coordinates of the sun.
#  - The green line (oval) shows the ecliptic.
#    - The sun moves along the ecliptic in the direction of increasing R.A. (counter-clockwise in the planisphere figure) such that it makes a full revolution in one year.
#    - The moon moves roughly (within 5.14°) along the ecliptic in the direction of increasing R.A. (counter-clockwise in the planisphere figure), completing a full revolution in one [sidereal month](https://en.wikipedia.org/wiki/Lunar_month#Sidereal_month) (a bit over 27 days), about 14° per day.
#  - The blue line (oval) shows the plane of the Milky Way.
#  - The black line shows the horizon at the time set by the MJD slider.
#  - The red line shows a zenith distince of 70° (airmass=2.9) at the time set by the MJD slider.
#
# Filled camera footprint mark completed visits starting befor the date and time set by the date/time slider.
# Faintly outlined camera footprints mark simulated visits that started after the time set by the date/time slider.
# Darkly outlined camera footprints mark simulated visits that started before it.
#
# The drop-down selects which simultion is to be shown for comparison with completed visits.

# %% [markdown]
# ## Visit parameter vs. time
#
# The scalar visit parameter to plot can be chosen with the drop-down in the upper left.
#
# The simulation with which completed visits should be compared can be selected from the drop-down at the top.

# %%
default_column = "altitude"
# Create the instance of bokeh.plotting.figure ourselves so
# we can set the width and height.

plot = bokeh.plotting.figure(
    y_axis_label=default_column,
    x_axis_label="Time (UTC)",
    frame_width=1024,
    frame_height=512,
)
fig = schedview.plot.visits.plot_visit_param_vs_time(
    visits,
    default_column,
    plot=plot,
    show_column_selector=True,
    show_sim_selector=True,
    size=10,
    marker_transform=sim_marker_mapper,
    default_sim=sim_labels[1],
)
bokeh.io.show(fig)

# %% [markdown]
# ## Timing plot
#
# The timing plot plots the time "as observed" vs. the time "as simulated" where completed visits correspond to simulated ones.
#
# The drop-down selects the simulation with which "as observed" is to be compared.

# %%
if no_visits:
    print("No completed science survey visits for this night, so no timing plot.")
else:
    obs_columns = list(
        set(
            [
                "s_ra",
                "s_dec",
                "azimuth",
                "altitude",
                "HA",
                "science_program",
                "observation_reason",
                "target_name",
                "start_timestamp",
            ]
        )
        & set(visits.columns)
    )
    sim_columns = list(
        set(
            [
                "azimuth",
                "altitude",
                "HA",
                "target_name",
                "observation_reason",
                "science_program",
                "sim_index",
                "start_timestamp",
                "label",
            ]
        )
        & set(visits.columns)
    )
    offsets = schedview.compute.compute_obs_sim_offsets(visits)
    enhanced_offsets = (
        offsets.reset_index()
        .merge(
            visits.set_index("sim_index").loc[0, obs_columns],
            how="left",
            left_on="obs_time",
            right_on="start_timestamp",
            sort=True,
            suffixes=("", "_obs"),
        )
        .drop(columns=["start_timestamp"])
        .merge(
            visits.reset_index().loc[:, sim_columns],
            how="left",
            left_on=("sim_index", "sim_time"),
            right_on=("sim_index", "start_timestamp"),
            suffixes=("_obs", "_sim"),
        )
        .drop(columns=["start_timestamp"])
        .set_index(["sim_index", POINTING_COL, "band"])
    )

    tooltips = [
        ("R.A. (obs)", "@s_ra" + "\u00b0"),
        ("Decl. (obs)", "@s_dec" + "\u00b0"),
        ("band", "@band"),
        ("simulation", "@label"),
        ("Start time (obs)", "@obs_time{%F %T} UTC"),
        ("Start time (sim)", "@sim_time{%F %T} UTC"),
        ("Observation reason (obs)", "@observation_reason_obs"),
        ("Observation reason (sim)", "@observation_reason_sim"),
        ("Target name (obs)", "@target_name_obs"),
        ("Target name (sim)", "@target_name_sim"),
        ("Science program (obs)", "@science_program_obs"),
        ("Science program (sim)", "@science_program_sim"),
    ]

    if len(enhanced_offsets) > 0:
        obs_vs_sim_time_plot = schedview.plot.plot_obs_vs_sim_time(enhanced_offsets, tooltips)
        bokeh.io.show(obs_vs_sim_time_plot)
    else:
        print("No matches from which to compute offsets.")

# %% [markdown]
# ## Common visits and offsets between them

# %%
if no_visits:
    print("No completed science survey visits on this night, so no offsets between completed and simulated visits.")
elif len(offsets) == 0:
    print("No common visits (so no offsets)")
else:
    offset_stats = schedview.compute.compute_offset_stats(offsets, visits, hhmmss=True)
    with pd.option_context("display.max_colwidth", 512):
        display(offset_stats)

# %% [markdown]
# In the above table:
#
#  - **label** is the text label assigned to the simulation in the simulation archive.
#  - **obs count** is the total number of visits with blocks corresponding to survey science from ConsDB (the database of completed exposures).
#  - **sim count** is the total number of visits in the simulation for the night.
#  - **match count** is the number of visits the completed and simulations have in common, where visits are matched by band and coordinates. When multiple visits are completed at the same band/pointing combination, the number of matches is the lesser of the number of times it was completed and the number of times it was simulated. For example, if a band/pointing appears 5 times in the simulation but was completed 3 times, it would count as 3 matches.
#  - **#match/#obs** is the ratio of **match count** to **obs count**, as defined above.
#  - **#match/#sim** is the ratio of **match count** to **sim count**, as defived above.
#
# The remaining columns show the statistics for offsets between the start times in simulation from those completed (including only those visits with matches). (MAD is the **m**edian **a**bsolute **d**eviation, the median of the absolute value of the offsets.)

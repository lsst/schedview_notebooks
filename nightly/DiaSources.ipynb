# %%
day_obs = 20260606
make_sky_plots = True

# %% [markdown]
# # Diasources and Visits
#
# Query the number of diaSources reported in `lsst.prompt.prod.numDiaSourcesGood` and merge with visit information.

# %%
# import getpass

# # This forces an upgrade of the necessary packages, pip installing into the user's space
# if "noteburst" in getpass.getuser():
#     print("Running in times square")
#     print("Updating rubin_nights")
#     # Note that a regular user running this in jupyter lab can run these commands to get the packages pip installed as well
#     !pip install --user --upgrade git+https://github.com/lsst-sims/rubin_nights.git --no-deps --no-build-isolation > /dev/null 2>&1

# %%
import os
from astropy.time import Time, TimeDelta
from astropy.coordinates import EarthLocation
from IPython.display import display, HTML
from rubin_nights import connections
from rubin_nights.influx_query import InfluxQueryClient
from rubin_nights import pipelines_metrics
import rubin_nights.dayobs_utils as rn_dayobs

import numpy as np
import pandas as pd 

import rubin_sim.maf as maf
from lsst_survey_sim import plot

import matplotlib.pyplot as plt

import rubin_nights.plot_utils as rn_plots
colors = rn_plots.PlotStyles.band_colors
markers = rn_plots.PlotStyles.band_symbols

import logging
logging.getLogger('rubin_nights').setLevel(logging.INFO)

# %%
# Where is the notebook running? (RSPs are 'special')
current_location = os.getenv("EXTERNAL_INSTANCE_URL", "")

# RUBIN_SIM_DATA_DIR at usdf
if 'usdf' in current_location:
    os.environ["RUBIN_SIM_DATA_DIR"] = "/sdf/data/rubin/shared/rubin_sim_data"

endpoints = connections.get_clients()

# %%
# Single night
tstart, tend = rn_dayobs.day_obs_sunset_sunrise(day_obs, sun_alt=-12)

# OR .. 
#tstart = Time("2026-05-21T12:00:00")
#tend = Time("2026-05-25T12:00:00")

alertsum = pipelines_metrics.diasource_visit_summaries(tstart, tend, endpoints['pp'])

# %%
#fields = ['visit', 'exposure', 'detector', 'day_obs', 'ra', 'dec', 'band', 'nPsfStar', 'psfArea', 'psfSigma', 'skyBg', 'skyNoise', 'zeroPoint']
#tt2 = endpoints['pp'].select_time_series("lsst.prompt.prod.initialPviSummaryMetrics", fields, tstart, tend)
#tt = tt2.groupby("visit").agg({"band": "first", "zeroPoint": "median", "psfSigma": "median", "skyBg": "median", "skyNoise": "median"}, axis=1)

# %%
visits = endpoints['consdb_tap'].get_visits("lsstcam", tstart, tend, visit_constraint="img_type = 'science'")
print("Science visits acquired in programs:", list(visits.science_program.unique()))

# %%
# vid = list(tt.index.values.astype(int))
# s = visits.query("visit_id in @vid")
# for b in 'ugrizy':
#     plt.plot(s.query("band == @b").seq_num, s.query("band == @b").zero_point_median.values - tt.query("band == @b").zeroPoint.values, colors[b], linestyle='', marker='.')
# plt.xlabel("seq_num")
# plt.ylabel("RA zero_point_median - PP median zeroPoint")
# q = s.zero_point_median.values - tt.zeroPoint.values
# s.iloc[np.where(abs(q) > 0.02)][['visit_id', 'band', 'target_name', 'observation_reason', 'science_program']]

# %%
print("NOTE: 'allDiaSources' reported from lsst.prompt.prod.numDiaSourcesGood should be close to the number of alerts, but is not coming from the alert stream.")
print("This is the content reported in the `lsst.prompt.prod.numDiaSourcesGood`, `lsst.prompt.prod.numSsObjects` and `lsst.prompt.prod.numDirectSsObjects`")
print("")
print("number of visits:", len(visits))
print("number of visits with numAllDiaSources", len(alertsum.query("numAllDiaSources_sum > 0")))
print("number of visits with associated diasource SSOs:", len(alertsum.query("numSsObjects_sum >0")))
print("number of visits with direct associated SSOs:", len(alertsum.query("numDirectSsObjects_sum > 0")))
print("")
print("number of all diasources:", alertsum.numAllDiaSources_sum.sum())
print("number of associated sso objects in diasources:", alertsum.numSsObjects_sum.sum())
print("number of direct associated sso objects:", alertsum.numDirectSsObjects_sum.sum())

# %%
if len(visits) > 0 and len(alertsum) > 0:
    vv = pd.merge(visits, alertsum, left_on='visit_id', right_index=True, how='outer')
    cols = ['visit_id', 'observation_reason', 'target_name', 'obs_start', 'band', 's_ra', 's_dec', 'sky_rotation', 'clouds', 'fwhm_eff', 'cat_m5', 
            'numAllDiaSources_sum', 'numAllDiaSources_median', 'nDiaDetectors_count', 
            'numSsObjects_sum', 'nSsDetectors_count', 'numDirectSsObjects_sum', 'nDSsDetectors_count']
else:
    cols = ['numAllDiaSources_sum', 'numAllDiaSources_median', 'nDiaDetectors_count', 
            'numSsObjects_sum', 'nSsDetectors_count', 'numDirectSsObjects_sum', 'nDSsDetectors_count']
    new_df = pd.DataFrame(np.zeros((len(visits), len(cols))), index=visits.index, columns=cols)
    vv = pd.merge(visits, new_df, left_index=True, right_index=True)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import column
from bokeh.models import HoverTool, ColumnDataSource, Range1d, BoxAnnotation
from bokeh.plotting import figure, output_notebook, show

# %%
matplotlib_to_bokeh = {
    'o': 'circle',
    's': 'square',
    '^': 'triangle',
    'v': 'inverted_triangle',
    'd': 'diamond',
    'D': 'diamond',
    'p': 'hex',
    'H': 'hex',
    '*': 'asterisk',
    '+': 'cross',
    'x': 'x',
    'X': 'x',
    '|': 'dash',
    '_': 'dash',
    '.': 'dot',
}

bokeh_markers = {k: matplotlib_to_bokeh.get(v, 'circle') for k, v in markers.items()}


output_notebook()  # Enable display in Jupyter

if len(vv) > 0:
    
    # Create list to hold all subplot figures
    figs = []
    sources = []
    
    # Define y-axis columns and labels
    if vv.numDirectSsObjects_sum.sum() > 0:
        subplots_config = [
            ('fwhm_geom', 'fwhm (arcsecond)'),
            ('clouds', 'cloud extinction'),
            ('cat_m5', 'estimated m5'),
            ('numAllDiaSources_sum', 'N DiaSources'),
            ('nDiaDetectors_count', 'N DiaDetectors'),
            ('numSsObjects_sum', 'N SsObjects'),
            ('numDirectSsObjects_sum', 'N Direct SsObjects'),
            ('ecliptic_lat', 'Ecliptic Latitude'),
            ('galactic_lat', 'Galactic Latitude'),
        ]
    else:
        subplots_config = [
            ('fwhm_geom', 'fwhm (arcsecond)'),
            ('clouds', 'cloud extinction'),
            ('cat_m5', 'estimated m5'),
            ('numAllDiaSources_sum', 'N DiaSources'),
            ('nDiaDetectors_count', 'N DiaDetectors'),
            ('numSsObjects_sum', 'N SsObjects'),
            ('ecliptic_lat', 'Ecliptic Latitude'),
            ('galactic_lat', 'Galactic Latitude'),
        ]
    # Create a shared x-axis range
    x = Time(vv.obs_start_mjd, format='mjd').to_datetime()
    #shared_range = Range1d(start=q.obs_start_mjd.min(), end=q.obs_start_mjd.max())
    shared_range = Range1d(start=x.min(), end=x.max())
    
    # Get day title
    day_title = vv.day_obs.unique()
    if len(day_title) == 1:
        day_title = day_title[0]
    else:
        day_title = f"{day_title.min()} - {day_title.max()}"

    
    for col_name, y_label in subplots_config:
        # Create figure
        p = figure(
            title=y_label,
            x_axis_label='MJD' if col_name == 'galactic_lat' else '',
            y_axis_label=y_label,
            width=1200,
            height=200,
            toolbar_location='right',
            tools='pan,wheel_zoom,box_zoom,reset,save',
            x_range=shared_range,
        )

        
        # Add background line (gray, low alpha)
        p.line(
            x, #q.obs_start_mjd,
            vv[col_name],
            line_color='gray',
            line_alpha=0.3,
            line_width=1
        )

        
        # Add markers for each band
        for b in vv.band.unique():
            qq = vv.query("band == @b").reset_index(drop=True)
            xx = Time(qq.obs_start_mjd, format='mjd').to_datetime()
            # Create a ColumnDataSource with all the data you want in hover
            source = ColumnDataSource(data=dict(
                x=xx, 
                y=qq[col_name],
                visit_id=qq.visit_id,
                mjd=qq.obs_start_mjd,
                band=qq.band,
                obs_start=qq.obs_start,
                clouds=qq.clouds,
                fwhm_geom=qq.fwhm_geom,
                scheduler_note=qq.scheduler_note,
            ))
            sources.append(source)
            
            # Plot the points
            p.scatter(
                'x', 'y',
                source=source,
                marker=bokeh_markers[b],
                size=8,
                color=colors[b],
                legend_label=b,
                alpha=0.8,
                hover_color='red',
            )

        # Style
        p.legend.click_policy = "hide"
        p.legend.glyph_width = 15   # Shrink marker width
        p.legend.spacing = 2        # Reduce space between items
        p.legend.margin = 3        # Reduce padding around legend
        p.grid.grid_line_alpha = 0.3
        p.add_layout(p.legend[0], "right") 

        # For the ecliptic and galactic latitude plots, add a background gradient
        if "_lat" in col_name:
            n_steps = 50
            y_min, y_max = 30, 90
            step = (y_max - y_min) / n_steps
            for i in range(n_steps):
                bottom = y_min + i * step
                top = bottom + step
                alpha = 0.4 * (i / n_steps)
                box = BoxAnnotation(
                    bottom=bottom, top=top,
                    fill_color="gray", fill_alpha=alpha,
                    line_color=None
                )
                p.add_layout(box)

            y_min, y_max = -90, -30
            step = (y_max - y_min) / n_steps
            for i in range(n_steps):
                bottom = y_min + i * step
                top = bottom + step
                alpha = 0.4 * (1 - i / n_steps)
                box = BoxAnnotation(
                    bottom=bottom, top=top,
                    fill_color="gray", fill_alpha=alpha,
                    line_color=None
                )
                p.add_layout(box)

        
        figs.append(p)

    # Add a hovertool to all figures    
    for fig, spc in zip(figs, subplots_config):
        hover = HoverTool(tooltips=[
            ('Visit ID', '@visit_id'),
            ('MJD', '@mjd{0.000000}'),
            ('SchedNote', '@scheduler_note'),
            (spc[1], '@y{0.00}'),           
        ])
        fig.add_tools(hover)


    
    # Combine all figures, add title
    layout = column(*figs)
    
    # Display
    show(layout)

# %%
# from rubin_nights import plot_utils
# camera_df = plot_utils.lsst_camera_df()

# visit_id = "2026052300358"

# fig, ax = plt.subplots(1, 1, figsize=(14, 11))
# fig, ax = plot_utils.detector_plot(key = 'numAllDiaSources',
#     detector_values = dia_det.query("visit == @visit_id"),
#     camera_df = camera_df,
#     title = f"diasources in visit {visit_id}", ax=ax)

# ccdquicklook = endpoints['consdb_tap'].query_ccdvisits("lsstcam", int(visit_id))

# fig, ax = plt.subplots(1, 1, figsize=(14, 11))
# key = 'zero_point'
# key = 'psf_sigma'
# fig, ax = plot_utils.detector_plot(key =  key,
#     detector_values = ccdquicklook,
#     camera_df = camera_df,
#     title = f"{key} in visit {visit_id}", ax=ax)

# %%
lsst_site = EarthLocation.of_site("rubin")
mean_lst = Time(tstart + (tend - tstart)/2, location=lsst_site).sidereal_time("mean")
lon_0 = mean_lst.deg
# roughly catch if we might have covered multiple days and thus ended up with 'daytime'
if len(visits.day_obs.unique()) > 0:
    lon_0 = lon_0 - 45

# %%
# all kinds of detections including direct sso objects?
#q = vv.query("numGoodDiaSources_sum > 0 or numDirectSsObjects_sum > 0")
# or just alerts
#q = vv.query("numGoodDiaSources_sum > 0")
# or all visits
q = vv
if make_sky_plots and len(q) > 0:

    nvisits_v = {}
    m_nvis = maf.CountMetric(col='obs_start_mjd', metric_name = "Nvisits")
    s = maf.HealpixSlicer(nside=64, lon_col='s_ra', lat_col='s_dec', rot_sky_pos_col_name = 'sky_rotation')
    for b in ['u', 'g', 'r', 'i', 'z', 'y', 'all']:
        constraint = f"{b}"
        if b == 'all':
            opsvis = q.to_records()
        else:
            opsvis = q.query("band == @b").to_records()
        nvisits_v[b] = maf.MetricBundle(m_nvis, s, constraint)
        g = maf.MetricBundleGroup({f'nvisits {b}': nvisits_v[b],}, None)
        if len(opsvis) > 0:
            g.run_current(constraint, opsvis)    

    background = plot.get_background(nside=64)
    
    fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(16, 10),)
    axdict = {"u": ax[0][0], "g": ax[0][1], "r": ax[0][2],
              "i": ax[1][0], "z": ax[1][1], "y": ax[1][2], "all": None}
    for b in ["u", "g", "r", "i", "z", "y"]:
        if nvisits_v[b].metric_values is not None:
            if len(nvisits_v[b].metric_values.compressed()) > 1:
                vmax = np.percentile(nvisits_v[b].metric_values.compressed(), 95)
            else:
                vmax = None
            label_dec = False
            if b == 'u' or b == 'i':
                label_dec = True
            fig = plot.make_plot(nvisits_v[b], background=background, proj='McBryde', lon_0=lon_0, vmax=vmax, ax=axdict[b], title=f"LSSTCam band visits {b}", label_dec=label_dec)
    fig.tight_layout()
    
    vmax = np.percentile(nvisits_v['all'].metric_values.compressed(), 95)
    fig = plot.make_plot(nvisits_v['all'], background=background, proj='mcbryde', lon_0=lon_0, vmin=None, vmax=vmax, ax=None, title=f"LSSTCam visits")

# %%
# # Read deployed template maps
# import healpy as hp
# coverage_dir = "/Users/lynnej/opsim/templates"
# template_coverage = {}
# for b in 'ugrizy':
#     template_coverage[b] = hp.read_map(os.path.join(coverage_dir, f"template_coverage_healpix_{b}_nside64.fits"))

# %%
# background = plot.get_background(nside=64)

# b = 'r'
# mval = nvisits_v[b].metric_values.copy()
# #mval = np.ma.MaskedArray(np.zeros(hp.nside2npix(64)))
# if mval is not None:
#     #vmax = np.percentile(mval.compressed(), 95)
#     alpha = np.where(np.isnan(background), 0, background)
#     alpha = np.where(alpha> 0.45, 0.40, alpha)
#     alpha = np.where(mval.filled(0) > 0, 0.45, alpha)
#     alpha = np.where(template_coverage[b] > 0, 0.5, alpha)
#     alpha = np.where((template_coverage[b] > 0) & (mval.filled(0) > 0), 1, alpha)
#     # This anchors alpha, in case there is no overlap of template&mval.
#     alpha[0:10] = 1
#     rot = (lon_0 - 90, 0, 0)
#     fig = plt.figure(figsize=(12, 8))
#     if len(visits.day_obs.unique()) > 1:
#         title=f"{visits.day_obs.min()} - {visits.day_obs.max()} {b} band"
#     else:
#         title = f"{visits.day_obs.unique()} {b} band"
#     hp.mollview(mval.filled(0), alpha=alpha, rot=rot, min=0, max=3, title=title, fig=fig, unit='Number of visits')
#     hp.graticule()

# %%
# overlaps = np.zeros(hp.nside2npix(64))
# for b in 'ugrizy':
#     if nvisits_v[b].metric_values is not None:
#         overlaps += np.where((nvisits_v[b].metric_values.filled(0) > 0) & (template_coverage[b] > 0), 1, 0)    
# overlaps = np.where(overlaps == 0, np.nan, overlaps)
# alpha = np.where(np.isnan(background), 0, background)
# alpha = np.where(alpha> 0.5, 0.50, alpha)
# alpha = np.where(overlaps > 0, 1, alpha)
# hp.mollview(overlaps, alpha=alpha, rot = rot)
# hp.graticule()

# %%
# all kinds of detections including direct sso objects?
#q = vv.query("numGoodDiaSources_sum > 0 or numDirectSsObjects_sum > 0")
# or just alerts
if len(vv) > 0:
    q = vv.query("numAllDiaSources_sum > 0")
if make_sky_plots and len(q) > 0:
    nvisits = {}
    m_nvis = maf.CountMetric(col='obs_start_mjd', metric_name = "Nvisits")
    s = maf.HealpixSlicer(nside=64, lon_col='s_ra', lat_col='s_dec', rot_sky_pos_col_name = 'sky_rotation')
    for b in ['u', 'g', 'r', 'i', 'z', 'y', 'all']:
        constraint = f"{b}"
        if b == 'all':
            opsvis = q.to_records()
        else:
            opsvis = q.query("band == @b").to_records()
        nvisits[b] = maf.MetricBundle(m_nvis, s, constraint)
        g = maf.MetricBundleGroup({f'nvisits {b}': nvisits[b],}, None)
        if len(opsvis) > 0:
            g.run_current(constraint, opsvis)    

    background = plot.get_background(nside=64)
    
    fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(16, 10),)
    axdict = {"u": ax[0][0], "g": ax[0][1], "r": ax[0][2],
              "i": ax[1][0], "z": ax[1][1], "y": ax[1][2], "all": None}
    for b in ["u", "g", "r", "i", "z", "y"]:
        if nvisits[b].metric_values is not None:
            if len(nvisits[b].metric_values.compressed()) > 1:
                vmax = np.percentile(nvisits[b].metric_values.compressed(), 95)
            else:
                vmax = None
            label_dec = False
            if b == 'u' or b == 'i':
                label_dec = True
            fig = plot.make_plot(nvisits[b], background=background, proj='McBryde', lon_0=lon_0, vmax=vmax, ax=axdict[b], title=f"LSSTCam band with DiaSources {b}", label_dec=label_dec)
    fig.tight_layout()
    
    vmax = np.percentile(nvisits['all'].metric_values.compressed(), 95)
    fig = plot.make_plot(nvisits['all'], background=background, proj='mcbryde', lon_0=lon_0, vmin=None, vmax=vmax, ax=None, title=f"LSSTCam visits with DiaSources")

# %%
# all kinds of detections including direct sso objects?
#q = vv.query("numGoodDiaSources_sum > 0 or numDirectSsObjects_sum > 0")
# or just direct associations of ssos
if len(vv) > 0:
    q = vv.query("numDirectSsObjects_sum > 0")
if make_sky_plots and len(q) > 0:

    nvisits_s = {}
    m_nvis = maf.CountMetric(col='obs_start_mjd', metric_name = "Nvisits")
    s = maf.HealpixSlicer(nside=64, lon_col='s_ra', lat_col='s_dec', rot_sky_pos_col_name = 'sky_rotation')
    for b in ['u', 'g', 'r', 'i', 'z', 'y', 'all']:
        constraint = f"{b}"
        if b == 'all':
            opsvis = q.to_records()
        else:
            opsvis = q.query("band == @b").to_records()
        nvisits_s[b] = maf.MetricBundle(m_nvis, s, constraint)
        g = maf.MetricBundleGroup({f'nvisits {b}': nvisits_s[b],}, None)
        if len(opsvis) > 0:
            g.run_current(constraint, opsvis)    

    background = plot.get_background(nside=64)
    
    fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(16, 10),)
    axdict = {"u": ax[0][0], "g": ax[0][1], "r": ax[0][2],
              "i": ax[1][0], "z": ax[1][1], "y": ax[1][2], "all": None}
    for b in ["u", "g", "r", "i", "z", "y"]:
        if nvisits_s[b].metric_values is not None:
            if len(nvisits_s[b].metric_values.compressed()) > 1:
                vmax = np.percentile(nvisits_s[b].metric_values.compressed(), 95)
            else:
                vmax = None
            label_dec = False
            if b == 'u' or b == 'i':
                label_dec = True
            fig = plot.make_plot(nvisits_s[b], background=background, proj='McBryde', lon_0=lon_0, vmax=vmax, ax=axdict[b], title=f"LSSTCam band with DirectSSOs {b}", label_dec=label_dec)
    fig.tight_layout()
    
    vmax = np.percentile(nvisits_s['all'].metric_values.compressed(), 95)
    fig = plot.make_plot(nvisits_s['all'], background=background, proj='mcbryde', lon_0=lon_0, vmin=None, vmax=vmax, ax=None, title=f"LSSTCam visits with DirectSSOs")

# %%
# if len(vv) > 0:
#     print("DIASOURCES")
#     qqq = vv
#     fig, ax = plt.subplots(1, 3, figsize=(20, 6))
#     subs = ['ddf not cosmos', 'ddf cosmos', 'too', 'twilight_near_sun', 'other' ]
#     exclude = np.array([])
#     for tt in subs:
#         if tt == 'ddf not cosmos':
#             qq = qqq.query("target_name.str.contains('ddf_') and ~target_name.str.contains('cosmos')")
#             exclude = np.concat([exclude, qq.index])
#             marker = 's'
#         elif tt == 'ddf cosmos':
#             qq = qqq.query("target_name.str.contains('cosmos')")
#             exclude = np.concat([exclude, qq.index])
#             marker = 'v'
#         elif tt == 'too':
#             qq = qqq.query("observation_reason.str.contains('too')")
#             exclude = np.concat([exclude, qq.index])
#             marker = '*'
#         elif tt == 'twilight_near_sun':
#             qq = qqq.query("observation_reason.str.contains('twilight_near_sun')")
#             exclude = np.concat([exclude, qq.index])
#             marker = '>'
#         else:
#             qq = qqq.query("index not in @exclude")
#             marker = 'o'
        
#         for b in qq.band.unique():
#             q = qq.query("band == @b and numAllDiaSources_sum > 0")
#             #print(tt, b, len(q))
#             if len(q) > 0:
#                 if not np.all(np.isnan(q.cat_m5)) and not np.all(np.isnan(q.numAllDiaSources_sum)):
#                     scatter1 = ax[0].scatter(q.cat_m5, q.numAllDiaSources_sum, s=q.nDiaDetectors_count/189*20 + 5,
#                                             marker=marker, color=colors[b], linestyle='', label=f"{b} {tt}")
#                     scatter2 = ax[1].scatter(q.galactic_lat, q.numAllDiaSources_sum, s=(q.cat_m5 - q.cat_m5.min())*5 + 9,
#                                             marker=marker, color=colors[b], linestyle='', label=f"{b} {tt}")
#                     scatter3 = ax[2].scatter(q.nDiaDetectors_count, q.numAllDiaSources_sum, s=(q.cat_m5 - q.cat_m5.min())*5 + 9, #color=colors[b], 
#                                               marker=marker, color=colors[b], linestyle='', label=f"{b} {tt}")

#     # ax[0].legend()
#     ax[0].grid(alpha=0.3)
#     #x = np.arange(23, 25.5, .1)
#     #y = (x - 23.25) * (17500 - 2500)/(25-23.25) + 2500
#     #ax[0].plot(x, y, 'k:')
#     #ax[0].set_xlim(23, 25)
#     ax[0].set_xlabel("estimated limiting magnitude", fontsize='large')
#     ax[0].set_ylabel("nAllDiaSources per visit", fontsize='large')
#     day_title = vv.day_obs.unique()
#     if len(day_title) == 1:
#         day_title = day_title[0]
#     else:
#         day_title = f"{day_title.min()} - {day_title.max()}"
#     ax[0].set_title(f"Dayobs {day_title}", fontsize='large')

#     ax[1].grid(alpha=0.3)
#     ax[1].set_xlabel("Galactic Latitude (deg)", fontsize='large')
#     ax[1].set_ylabel("nAllDiaSources per visit", fontsize='large')
#     ax[1].set_title(f"Dayobs {day_title}", fontsize='large')
    
#     ax[2].legend(loc=(1.01, 0.1))
#     ax[2].grid(alpha=0.3)
#     ax[2].set_xlabel("nDiaDetectors per visit")
#     ax[2].set_ylabel("nAllDiaSources per visit", fontsize='large')
#     ax[2].set_title(f"Dayobs {day_title}", fontsize='large')

# %%
from bokeh.models import ColumnDataSource, Legend, LegendItem
from bokeh.layouts import row

def scale_to_range(series, min_size=3, max_size=10):
    s = series - series.min()
    rng = s.max()
    if rng == 0:
        return np.full(len(s), (min_size + max_size) / 2)
    return (s / rng) * (max_size - min_size) + min_size

if len(vv) > 0:
    print("DIASources")
    qqq = vv

    day_title = vv.day_obs.unique()
    if len(day_title) == 1:
        day_title = day_title[0]
    else:
        day_title = f"{day_title.min()} - {day_title.max()}"

    # Bokeh marker map (matplotlib -> bokeh)
    marker_map = {
        's': 'square',
        'v': 'inverted_triangle',
        '*': 'asterisk',
        '>': 'triangle',
        'o': 'circle',
    }

    common = dict(width=700, height=500, toolbar_location="above")
    p0 = figure(**common, x_axis_label="Estimated Limiting Magnitude",
                y_axis_label="nAllDiaSources per visit",
                title=f"Dayobs {day_title}")
    p1 = figure(**common, x_axis_label="Galactic Latitude (deg)",
                y_axis_label="nAllDiaSources per visit",
                title=f"Dayobs {day_title}")
    
    for p in [p0, p1]:
        p.grid.grid_line_alpha = 0.3

    legend_items = {p0: [], p1: [],}

    subs = ['ddf not cosmos', 'ddf cosmos', 'too', 'twilight_near_sun', 'other']
    exclude = np.array([])

    for tt in subs:
        if tt == 'ddf not cosmos':
            qq = qqq.query("target_name.str.contains('ddf_') and ~target_name.str.contains('cosmos')")
            exclude = np.concat([exclude, qq.index])
            marker = 's'
        elif tt == 'ddf cosmos':
            qq = qqq.query("target_name.str.contains('cosmos')")
            exclude = np.concat([exclude, qq.index])
            marker = 'v'
        elif tt == 'too':
            qq = qqq.query("observation_reason.str.contains('too')")
            exclude = np.concat([exclude, qq.index])
            marker = '*'
        elif tt == 'twilight_near_sun':
            qq = qqq.query("observation_reason.str.contains('twilight_near_sun')")
            exclude = np.concat([exclude, qq.index])
            marker = '>'
        else:
            qq = qqq.query("index not in @exclude")
            marker = 'o'

        bk_marker = marker_map[marker]

        for b in qq.band.unique():
            q = qq.query("band == @b and numAllDiaSources_sum > 0")
            if len(q) > 0:
                if not np.all(np.isnan(q.cat_m5)) and not np.all(np.isnan(q.numAllDiaSources_sum)):
                    color = colors[b]
                    label = f"{b} {tt}"

                    size0 = scale_to_range(q.nDiaDetectors_count).tolist()                    
                    src = ColumnDataSource(dict(          
                        numDiaSources=q.numAllDiaSources_sum,
                        nDiaDetectors_count=q.nDiaDetectors_count,
                        size=size0,
                        visit_id=q.visit_id,
                        band=q.band,
                        galactic_lat=q.galactic_lat,                        
                        m5=q.cat_m5,
                        obs_start=q.obs_start,
                        clouds=q.clouds,
                        fwhm_geom=q.fwhm_geom,
                        scheduler_note=q.scheduler_note,
                    ))
                    r0 = p0.scatter('m5', 'numDiaSources', size='size', marker=bk_marker,
                                    color=color, source=src)

                    r1 = p1.scatter('galactic_lat', 'numDiaSources', size='size', marker=bk_marker,
                                    color=color, source=src)

                    for p, r in [(p0, r0), (p1, r1)]:
                        legend_items[p].append(LegendItem(label=label, renderers=[r]))

    # Add legend
    for p in [p0, p1]:
        if legend_items[p]:
            legend = Legend(items=legend_items[p], location="center")
            p.add_layout(legend, 'right')
        p.legend.click_policy = "hide"
        p.legend.glyph_width = 15   # Shrink marker width
        p.legend.spacing = 2        # Reduce space between items
        p.legend.margin = 3        # Reduce padding around legend

    # Add hovers
    for p in [p0, p1,]:
        hover = HoverTool(tooltips=[
            ('Visit ID', '@visit_id'),
            ('NDiaSources', '@numDiaSources{0.00}'),
            ('Ndetectors', '@nDiaDetectors_count'),
            ('Band', '@band'),
            ('M5', '@m5{0.00}'),
            ('GalLat', '@galactic_lat{0.00}'),
            ('SchedNote', '@scheduler_note'),         
        ])
        p.add_tools(hover)

    show(row(p0, p1))

# %%
if len(vv) > 0:
    print("DIA SsObjects")
    qqq = vv

    day_title = vv.day_obs.unique()
    if len(day_title) == 1:
        day_title = day_title[0]
    else:
        day_title = f"{day_title.min()} - {day_title.max()}"

    # Bokeh marker map (matplotlib -> bokeh)
    marker_map = {
        's': 'square',
        'v': 'inverted_triangle',
        '*': 'asterisk',
        '>': 'triangle',
        'o': 'circle',
    }

    common = dict(width=700, height=500, toolbar_location="above")
    p0 = figure(**common, x_axis_label="Estimated Limiting Magnitude",
                y_axis_label="nDiaSsObjects per visit",
                title=f"Dayobs {day_title}")
    p1 = figure(**common, x_axis_label="Ecliptic Latitude (deg)",
                y_axis_label="nDiaSsObjects per visit",
                title=f"Dayobs {day_title}")
    
    for p in [p0, p1]:
        p.grid.grid_line_alpha = 0.3

    legend_items = {p0: [], p1: [],}

    subs = ['ddf not cosmos', 'ddf cosmos', 'too', 'twilight_near_sun', 'other']
    exclude = np.array([])

    for tt in subs:
        if tt == 'ddf not cosmos':
            qq = qqq.query("target_name.str.contains('ddf_') and ~target_name.str.contains('cosmos')")
            exclude = np.concat([exclude, qq.index])
            marker = 's'
        elif tt == 'ddf cosmos':
            qq = qqq.query("target_name.str.contains('cosmos')")
            exclude = np.concat([exclude, qq.index])
            marker = 'v'
        elif tt == 'too':
            qq = qqq.query("observation_reason.str.contains('too')")
            exclude = np.concat([exclude, qq.index])
            marker = '*'
        elif tt == 'twilight_near_sun':
            qq = qqq.query("observation_reason.str.contains('twilight_near_sun')")
            exclude = np.concat([exclude, qq.index])
            marker = '>'
        else:
            qq = qqq.query("index not in @exclude")
            marker = 'o'

        bk_marker = marker_map[marker]

        for b in qq.band.unique():
            q = qq.query("band == @b and numAllDiaSources_sum > 0")
            if len(q) > 0:
                if not np.all(np.isnan(q.cat_m5)) and not np.all(np.isnan(q.numAllDiaSources_sum)):
                    color = colors[b]
                    label = f"{b} {tt}"

                    size0 = scale_to_range(q.nDiaDetectors_count).tolist()                    
                    src = ColumnDataSource(dict(          
                        numSsObjects=q.numSsObjects_sum,
                        nDiaDetectors_count=q.nDiaDetectors_count,
                        size=size0,
                        visit_id=q.visit_id,
                        band=q.band,
                        ecliptic_lat=q.ecliptic_lat,                        
                        m5=q.cat_m5,
                        obs_start=q.obs_start,
                        clouds=q.clouds,
                        fwhm_geom=q.fwhm_geom,
                        scheduler_note=q.scheduler_note,
                    ))
                    r0 = p0.scatter('m5', 'numSsObjects', size='size', marker=bk_marker,
                                    color=color, source=src)

                    r1 = p1.scatter('ecliptic_lat', 'numSsObjects', size='size', marker=bk_marker,
                                    color=color, source=src)

                    for p, r in [(p0, r0), (p1, r1)]:
                        legend_items[p].append(LegendItem(label=label, renderers=[r]))

    # Add legend
    for p in [p0, p1]:
        if legend_items[p]:
            legend = Legend(items=legend_items[p], location="center")
            p.add_layout(legend, 'right')
        p.legend.click_policy = "hide"
        p.legend.glyph_width = 15   # Shrink marker width
        p.legend.spacing = 2        # Reduce space between items
        p.legend.margin = 3        # Reduce padding around legend

    # Add hovers
    for p in [p0, p1,]:
        hover = HoverTool(tooltips=[
            ('Visit ID', '@visit_id'),
            ('NDiaSources', '@numSsObjects{0.00}'),
            ('Ndetectors', '@nDiaDetectors_count'),
            ('Band', '@band'),
            ('M5', '@m5{0.00}'),
            ('EcLat', '@ecliptic_lat{0.00}'),
            ('SchedNote', '@scheduler_note'),         
        ])
        p.add_tools(hover)

    show(row(p0, p1))

# %%
# if len(vv) > 0:
#     print("DIA SsObjects")
#     qqq = vv
#     fig, ax = plt.subplots(1, 3, figsize=(20, 6))
#     subs = ['ddf not cosmos', 'ddf cosmos', 'too', 'twilight_near_sun', 'other' ]
#     exclude = np.array([])
#     for tt in subs:
#         if tt == 'ddf not cosmos':
#             qq = qqq.query("target_name.str.contains('ddf_') and ~target_name.str.contains('cosmos')")
#             exclude = np.concat([exclude, qq.index])
#             marker = 's'
#         elif tt == 'ddf cosmos':
#             qq = qqq.query("target_name.str.contains('cosmos')")
#             exclude = np.concat([exclude, qq.index])
#             marker = 'v'
#         elif tt == 'too':
#             qq = qqq.query("observation_reason.str.contains('too')")
#             exclude = np.concat([exclude, qq.index])
#             marker = '*'
#         elif tt == 'twilight_near_sun':
#             qq = qqq.query("observation_reason.str.contains('twilight_near_sun')")
#             exclude = np.concat([exclude, qq.index])
#             marker = '>'
#         else:
#             qq = qqq.query("index not in @exclude")
#             marker = 'o'
        
#         for b in qq.band.unique():
#             q = qq.query("band == @b and numAllDiaSources_sum > 0")
#             #print(tt, b, len(q))
#             if len(q) > 0:
#                 if not np.all(np.isnan(q.cat_m5)) and not np.all(np.isnan(q.numAllDiaSources_sum)):
#                     scatter1 = ax[0].scatter(q.cat_m5, q.numSsObjects_sum, s=q.nSsDetectors_count/189*20 + 5,
#                                             marker=marker, color=colors[b], linestyle='', label=f"{b} {tt}")
#                     scatter1 = ax[1].scatter(q.ecliptic_lat, q.numSsObjects_sum, s=(q.cat_m5 - q.cat_m5.min())*5 + 9,
#                                             marker=marker, color=colors[b], linestyle='', label=f"{b} {tt}")
#                     scatter3 = ax[2].scatter(q.nSsDetectors_count, q.numSsObjects_sum, s=(q.cat_m5 - q.cat_m5.min())*5 + 9, #color=colors[b], 
#                                               marker=marker, color=colors[b], linestyle='', label=f"{b} {tt}")

#     # ax[0].legend()
#     ax[0].grid(alpha=0.3)
#     #x = np.arange(23, 25.5, .1)
#     #y = (x - 23.25) * (17500 - 2500)/(25-23.25) + 2500
#     #ax[0].plot(x, y, 'k:')
#     #ax[0].set_xlim(23, 25)
#     ax[0].set_xlabel("estimated limiting magnitude", fontsize='large')
#     ax[0].set_ylabel("numSsObjects per visit", fontsize='large')
#     day_title = vv.day_obs.unique()
#     if len(day_title) == 1:
#         day_title = day_title[0]
#     else:
#         day_title = f"{day_title.min()} - {day_title.max()}"
#     ax[0].set_title(f"Dayobs {day_title}", fontsize='large')

#     ax[1].grid(alpha=0.3)
#     ax[1].set_xlabel("Ecliptic Latitude", fontsize='large')
#     ax[1].set_ylabel("numSsObjects per visit", fontsize='large')
#     ax[1].set_title(f"Dayobs {day_title}", fontsize='large')
    
#     ax[2].legend(loc=(1.01, 0.1))
#     ax[2].grid(alpha=0.3)
#     ax[2].set_xlabel("nSsDetectors per visit")
#     ax[2].set_ylabel("numSsObjects per visit", fontsize='large')
#     ax[2].set_title(f"Dayobs {day_title}", fontsize='large')

# %%
if len(vv) > 0 and len(vv.query("numDirectSsObjects_sum > 0")) > 0:
    qqq = vv    
    print("DIRECT SsObjects")
    fig, ax = plt.subplots(1, 2, figsize=(18, 8))
    subs = ['ddf not cosmos', 'ddf cosmos', 'too', 'twilight_near_sun', 'other' ]
    exclude = np.array([])
    for tt in subs:
        if tt == 'ddf not cosmos':
            qq = qqq.query("target_name.str.contains('ddf_') and ~target_name.str.contains('cosmos')")
            exclude = np.concat([exclude, qq.index])
            marker = 's'
        elif tt == 'ddf cosmos':
            qq = qqq.query("target_name.str.contains('cosmos')")
            exclude = np.concat([exclude, qq.index])
            marker = 'v'
        elif tt == 'too':
            qq = qqq.query("observation_reason.str.contains('too')")
            exclude = np.concat([exclude, qq.index])
            marker = '*'
        elif tt == 'twilight_near_sun':
            qq = qqq.query("observation_reason.str.contains('twilight_near_sun')")
            exclude = np.concat([exclude, qq.index])
            marker = '>'
        else:
            qq = qqq.query("index not in @exclude")
            marker = 'o'
        
        for b in qq.band.unique():
            q = qq.query("band == @b and numDirectSsObjects_sum > 0")
            if len(q) > 0:
                if not np.all(np.isnan(q.cat_m5)) and not np.all(np.isnan(q.numDirectSsObjects_sum)):
                    scatter1 = ax[0].scatter(q.ecliptic_lat, q.cat_m5,
                                            marker=marker, color=colors[b], linestyle='', label=f"{b} {tt}")
                    scatter2 = ax[1].scatter(q.ecliptic_lat, q.numDirectSsObjects_sum,
                                            marker=marker, color=colors[b], linestyle='', label=f"{b} {tt}")

    ax[0].grid(alpha=0.3)
    ax[0].set_xlabel("Ecliptic Latitude (deg)", fontsize='large')
    ax[0].set_ylabel("Estimated m5", fontsize='large')
    day_title = vv.day_obs.unique()
    if len(day_title) == 1:
        day_title = day_title[0]
    else:
        day_title = f"{day_title.min()} - {day_title.max()}"
    ax[0].set_title(f"Dayobs {day_title}", fontsize='large')

    ax[1].legend(loc=(1.01, 0.2))
    ax[1].grid(alpha=0.3)
    ax[1].set_xlabel("Ecliptic Latitude (deg)", fontsize='large')
    ax[1].set_ylabel("numDirectSsObjects_sum per visit", fontsize='large')
    day_title = vv.day_obs.unique()
    if len(day_title) == 1:
        day_title = day_title[0]
    else:
        day_title = f"{day_title.min()} - {day_title.max()}"
    ax[1].set_title(f"Dayobs {day_title}", fontsize='large')

# %%
cols= ['visit_id', 'numAllDiaSources_sum', 'numDirectSsObjects_sum', 'day_obs', 'band', 'eclip_lat', 'gal_lat', 'cat_m5', 'psf_sigma_median', 'clouds', 
       'target_name', 'observation_reason', 'science_program']
#vv.sort_values('numGoodDiaSources_sum', ascending=False)[cols].head(30)
#vv.sort_values('numDirectSsObjects_sum', ascending=False)[cols].head(30)
